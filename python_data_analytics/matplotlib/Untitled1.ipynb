# %%
# import the matplotlib module
import matplotlib.pyplot as plt

# import numpy as np
import numpy as np

# %%
def f(t):
    
    return np.exp(-t)*np.cos(2*np.pi*t)
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2))

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2))
plt.show()

# %%
# using numpy to generate random values
x_data = np.random.random(1000) * 100
y_data = np.random.random(1000) * 100

# Styling
# c = colors
# s = size pf markers
# marker = marker types
# alpha = transperency

plt.scatter(x_data, y_data, c = 'b', marker="*", s=150, alpha=0.3)

# %%
years = [2006 + x for x in range(16)]
earnings = [23, 45, 67, 23, 14, 56, 78, 67, 56 ,78, 45, 67, 89, 89, 76, 58]


plt.plot(years, earnings, c='g', lw=1, linestyle="--")
plt.show()

# %%
languages = ["C++", "Java", "Python", "Ruby", "Typescript"]
votes = [40, 20, 140, 10, 60]


plt.title("Most used programming language")
plt.xlabel("Progamming languages")
plt.ylabel("No. of votes")

plt.bar(languages, votes, color="#abb8c3", width=0.7)
plt.show()

# %%
languages = ["C++", "Java", "Python", "Ruby", "Typescript"]
votes = [40, 20, 140, 10, 60]


plt.title("Most used programming language")
plt.xlabel("Progamming languages")
plt.ylabel("No. of votes")

bars = plt.bar(languages, votes, color='#abb8c3', width=0.7)
bars[2].set_color("#abc8c5")
#bars[4].set_color("red")
plt.show()

# %%
# PIE chart
data = np.random.randint(10, 100, 6)
plt.pie(data)
plt.show()

# %%
genre = ['afrobeat', 'rap', 'gospel', 'fuji', 'highlife']
popularity = [100, 40, 80, 20, 10]
explodes = [0,0,0,0,0.3]
colors = ['#abb8c3','#7b1fa2','#009688', '#b80000', '#fcb900']

plt.pie(popularity, labels=genre, explode=explodes, colors=colors, autopct='%.0f%%')
plt.show()

# %%
# Doughnut Pie plot
circle = plt.Circle( (0,0), 0.7, color='white')

plt.pie(popularity, labels= genre, explode=explodes)
p = plt.gcf()
p.gca().add_artist(circle)


plt.title("Popularity of Highlife Genre Amongs Nigerian Youths")

plt.savefig("genre.png", bbox_inches='tight')
plt.show()

# %%
#cross table
plt.bar([1,3,5,7,9],[5,2,7,8,2], label="Elements one")
plt.bar([2,4,6,8,10], )
