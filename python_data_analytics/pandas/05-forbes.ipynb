# %% [markdown]
# ## Working with the forbes list

# %%
# import pandas
import pandas as pd

# %%
# load forbes data set
forbesList = pd.read_csv("forbes_2022.csv", sep=",")
print(forbesList)
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0      219000  2022      4
# 1        2                Jeff Bezos  58.0      171000  2022      4
# 2        3  Bernard Arnault & family  73.0      158000  2022      4
# 3        4                Bill Gates  66.0      129000  2022      4
# 4        5            Warren Buffett  91.0      118000  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0        1000  2022      4
# 2664  2578                Zhou Ruxin  59.0        1000  2022      4
# 2665  2578         Wen Zhou & family  57.0        1000  2022      4
# 2666  2578      Zhou Yifeng & family  43.0        1000  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0        1000  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
print(forbesList.head(2))
# Out:
#    rank  personName   age  finalWorth  year  month    category         source  \
# 0     1   Elon Musk  50.0      219000  2022      4  Automotive  Tesla, SpaceX
# 1     2  Jeff Bezos  58.0      171000  2022      4  Technology         Amazon
#
#          country       state  ... organization selfMade gender   birthDate  \
# 0  United States       Texas  ...        Tesla     True      M  28/06/1971
# 1  United States  Washington  ...       Amazon     True      M  12/01/1964
#
#           title philanthropyScore                 residenceMsa  \
# 0           CEO               1.0                          NaN
# 1  Entrepreneur               1.0  Seattle-Tacoma-Bellevue, WA
#
#    numberOfSiblings                                                bio  \
# 0               NaN  Elon Musk is working to revolutionize transpor...
# 1               NaN  Jeff Bezos founded e-commerce giant Amazon in ...
#
#                                                about
# ...

# %%
print(forbesList.tail())
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2663  2578            Zhang Yuqiang  66.0        1000  2022      4
# 2664  2578               Zhou Ruxin  59.0        1000  2022      4
# 2665  2578        Wen Zhou & family  57.0        1000  2022      4
# 2666  2578     Zhou Yifeng & family  43.0        1000  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0        1000  2022      4
#
#            category                   source country state  ... organization  \
# 2663  Manufacturing               Fiberglass   China   NaN  ...          NaN
# 2664     Technology               Navigation   China   NaN  ...          NaN
# 2665  Manufacturing                chemicals   China   NaN  ...          NaN
# 2666         Energy  liquefied petroleum gas   China   NaN  ...          NaN
# 2667  Manufacturing                polyester   China   NaN  ...          NaN
#
#      selfMade gender   birthDate title philanthropyScore residenceMsa  \
# ...

# %%
# filter data
filtered_row = forbesList[forbesList["category"] == "Automotive"]
print(filtered_row)
# Out:
#       rank              personName   age  finalWorth  year  month    category  \
# 0        1               Elon Musk  50.0      219000  2022      4  Automotive
# 28      29              Robin Zeng  53.0       44800  2022      4  Automotive
# 55      56         Susanne Klatten  59.0       24300  2022      4  Automotive
# 61      62                Li Shufu  58.0       23700  2022      4  Automotive
# 76      77           Stefan Quandt  55.0       20700  2022      4  Automotive
# ...    ...                     ...   ...         ...   ...    ...         ...
# 2430  2324  Jianfeng Wang & family  52.0        1200  2022      4  Automotive
# 2447  2448         A. Jayson Adair  52.0        1100  2022      4  Automotive
# 2501  2448          Suresh Krishna  85.0        1100  2022      4  Automotive
# 2544  2448         Venu Srinivasan  69.0        1100  2022      4  Automotive
# 2605  2578       Hiroshi Ishibashi  75.0        1000  2022      4  Automotive
#
# ...

# %%
# replace values in data set
replaced_category = forbesList.replace("Automotive", "Automobile")

print(replaced_category.head())
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0      219000  2022      4
# 1     2                Jeff Bezos  58.0      171000  2022      4
# 2     3  Bernard Arnault & family  73.0      158000  2022      4
# 3     4                Bill Gates  66.0      129000  2022      4
# 4     5            Warren Buffett  91.0      118000  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automobile       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %%
# remove data from dataframe 
remove_column = forbesList.drop('numberOfSiblings', axis=1)
print(remove_column.head(2))
# Out:
#    rank  personName   age  finalWorth  year  month    category         source  \
# 0     1   Elon Musk  50.0      219000  2022      4  Automotive  Tesla, SpaceX
# 1     2  Jeff Bezos  58.0      171000  2022      4  Technology         Amazon
#
#          country       state  ... countryOfCitizenship organization selfMade  \
# 0  United States       Texas  ...        United States        Tesla     True
# 1  United States  Washington  ...        United States       Amazon     True
#
#    gender   birthDate         title philanthropyScore  \
# 0       M  28/06/1971           CEO               1.0
# 1       M  12/01/1964  Entrepreneur               1.0
#
#                   residenceMsa  \
# 0                          NaN
# 1  Seattle-Tacoma-Bellevue, WA
#
#                                                  bio  \
# 0  Elon Musk is working to revolutionize transpor...
# 1  Jeff Bezos founded e-commerce giant Amazon in ...
#
#                                                about
# ...

# %%
new_forbes = forbesList.drop(['year','month', 'source', 'state', 'country', 'state', 'organization', 'philanthropyScore',
                             'birthDate', 'residenceMsa', 'bio', 'about', 'title', 'numberOfSiblings', 'city' ], axis=1)

print(new_forbes.head())
# Out:
#    rank                personName   age  finalWorth               category  \
# 0     1                 Elon Musk  50.0      219000             Automotive
# 1     2                Jeff Bezos  58.0      171000             Technology
# 2     3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3     4                Bill Gates  66.0      129000             Technology
# 4     5            Warren Buffett  91.0      118000  Finance & Investments
#
#   countryOfCitizenship  selfMade gender
# 0        United States      True      M
# 1        United States      True      M
# 2               France     False      M
# 3        United States      True      M
# 4        United States      True      M

# %%
print(new_forbes)
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0      219000             Automotive
# 1        2                Jeff Bezos  58.0      171000             Technology
# 2        3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3        4                Bill Gates  66.0      129000             Technology
# 4        5            Warren Buffett  91.0      118000  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0        1000          Manufacturing
# 2664  2578                Zhou Ruxin  59.0        1000             Technology
# 2665  2578         Wen Zhou & family  57.0        1000          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0        1000                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0        1000          Manufacturing
#
# ...

# %%
# get unique values in a column
countries = new_forbes["countryOfCitizenship"].unique()
print(countries)
print(len(countries))
# Out:
# ['United States' 'France' 'India' 'Mexico' 'China' 'Canada' 'Spain'
#  'Germany' 'Hong Kong' 'Italy' 'Australia' 'Austria' 'Japan' 'Indonesia'
#  'Switzerland' 'Chile' 'Russia' 'Singapore' 'Sweden' 'Czechia'
#  'United Kingdom' 'Brazil' 'Israel' 'Netherlands' 'Ireland' 'Nigeria'
#  'Denmark' 'Thailand' 'Cyprus' 'Malaysia' 'Taiwan' 'Monaco' 'Colombia'
#  'New Zealand' 'South Korea' 'Belgium' 'South Africa' 'Philippines'
#  'Egypt' 'Greece' 'Norway' 'Vietnam' 'Poland' 'Eswatini (Swaziland)'
#  'Peru' 'Algeria' 'Kazakhstan' 'Georgia' 'Portugal' 'Turkey' 'Finland'
#  'Ukraine' 'Argentina' 'Belize' 'Venezuela' 'Lebanon' 'Zimbabwe' 'Romania'
#  'United Arab Emirates' 'Oman' 'Iceland' 'Guernsey' 'Liechtenstein'
#  'Qatar' 'Morocco' 'Bulgaria' 'Macau' 'Slovakia' 'Barbados' 'Uruguay'
#  'Nepal' 'Tanzania' 'St. Kitts and Nevis' 'Hungary' 'Estonia']
# 75

# %%
europeSrting = """Albania
Andorra
Armenia
Austria
Azerbaijan
Belarus
Belgium
Bosniaand Herzegovina
Bulgaria
Croatia
Cyprus
Czechia
Denmark
Estonia
Finland
France
Georgia
Germany
Greece
Hungary
Iceland
Ireland
Italy
Kazakhstan
Kosovo
Latvia
Liechtenstein
Lithuania
Luxembourg
Malta
Moldova
Monaco
Montenegro
Netherlands
North Macedonia
Norway
Poland
Portugal
Romania
Russia
San Marino
Serbia
Slovakia
Slovenia
Spain
Sweden
Switzerland
Turkey
Ukraine
United Kingdom
VaticanCity
"""

europe = europeSrting.splitlines()
print(europe)
# Out:
# ['Albania', 'Andorra', 'Armenia', 'Austria', 'Azerbaijan', 'Belarus', 'Belgium', 'Bosniaand Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kazakhstan', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'Ukraine', 'United Kingdom', 'VaticanCity']

# %%
asiaString = """Afghanistan
Armenia
Azerbaijan
Bahrain
Bangladesh
Bhutan
Brunei
Cambodia
China
Cyprus
Georgia
India
Indonesia
Iran
Iraq
Israel
Japan
Jordan
Kazakhstan
Kuwait
Kyrgyzstan
Laos
Lebanon
Malaysia
Maldives
Mongolia
Myanmar
Nepal
North Korea
Oman
Pakistan
Palestine
Philippines
Qatar
Russia
Saudi Arabia
Singapore
South Korea
Sri Lanka
Syria
Taiwan
Tajikistan
Thailand
Timor-Leste
Turkey
Turkmenistan
United Arab Emirates (UAE)
Uzbekistan
Vietnam
Yemen
"""

asia = asiaString.splitlines()
print(asia)
# Out:
# ['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China', 'Cyprus', 'Georgia', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Palestine', 'Philippines', 'Qatar', 'Russia', 'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka', 'Syria', 'Taiwan', 'Tajikistan', 'Thailand', 'Timor-Leste', 'Turkey', 'Turkmenistan', 'United Arab Emirates (UAE)', 'Uzbekistan', 'Vietnam', 'Yemen']

# %%
africaString = """
Algeria
Angola
Benin
Botswana
Burkina Faso
Burundi
Cabo Verde
Cameroon
Central African Republic
Chad
Comoros
Congo, Democratic Republic of the
Congo, Republic of the
Cote d'Ivoire
Djibouti
Egypt
Equatorial Guinea
Eritrea
Eswatini
Ethiopia
Gabon
Gambia
Ghana
Guinea
Guinea-Bissau
Kenya
Lesotho
Liberia
Libya
Madagascar
Malawi
Mali
Mauritania
Mauritius
Morocco
Mozambique
Namibia
Niger
Nigeria
"""

africa = africaString.splitlines()
print(africa)
# Out:
# ['', 'Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo, Democratic Republic of the', 'Congo, Republic of the', "Cote d'Ivoire", 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria']

# %%
northAmericaString = """Antigua and Barbuda
Bahamas
Barbados
Belize
Canada
Costa Rica
Cuba
Dominica
Dominican Republic
El Salvador
Grenada
Guatemala
Haiti
Honduras
Jamaica
Mexico
Nicaragua
Panama
Saint Kitts and Nevis
Saint Lucia
Saint Vincent and the Grenadines
Trinidad and Tobago
United States
"""
northAmerica = northAmericaString.splitlines()
print(northAmerica)
# Out:
# ['Antigua and Barbuda', 'Bahamas', 'Barbados', 'Belize', 'Canada', 'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic', 'El Salvador', 'Grenada', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Trinidad and Tobago', 'United States', '']

# %%
southAmericaString = """Argentina
Bolivia
Brazil
Chile
Colombia
Ecuador
Guyana
Paraguay
Peru
Suriname
Uruguay
Venezuela
"""

southAmerica = southAmericaString.splitlines()
print(southAmerica)
# Out:
# ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela']

# %%
australiaString = """Australia
Fiji
Kiribati
Marshall Islands
Micronesia
Nauru
New Zealand
Palau
Papua New Guinea
Samoa
Solomon Islands
Tonga
Tuvalu
Vanuatu
"""

australia = australiaString.splitlines()
print(australia)
# Out:
# ['Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia', 'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa', 'Solomon Islands', 'Tonga', 'Tuvalu', 'Vanuatu']

# %%
###

continent = []

for i in range(len(new_forbes)):
    if new_forbes["countryOfCitizenship"][i] in africa:
        add = "Africa"
    elif new_forbes["countryOfCitizenship"][i] in europe:
        add = "Europe"
    elif new_forbes["countryOfCitizenship"][i] in asia:
        add = "Asia"
    elif new_forbes["countryOfCitizenship"][i] in northAmerica:
        add = "North America"
    elif new_forbes["countryOfCitizenship"][i] in southAmerica:
        add = "South America"
    elif new_forbes["countryOfCitizenship"][i] in australia:
        add = "Australia"
    else:
        add = None
    continent.append(add)
    
#create a new column to assign BMI scores
new_forbes['continent'] = continent

print(new_forbes)
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0      219000             Automotive
# 1        2                Jeff Bezos  58.0      171000             Technology
# 2        3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3        4                Bill Gates  66.0      129000             Technology
# 4        5            Warren Buffett  91.0      118000  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0        1000          Manufacturing
# 2664  2578                Zhou Ruxin  59.0        1000             Technology
# 2665  2578         Wen Zhou & family  57.0        1000          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0        1000                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0        1000          Manufacturing
#
# ...

# %%
age_classification = []
#weight/(height**2)
for i in range(len(new_forbes)):
    if new_forbes["age"][i] < 45:
        result = 'youth'
    elif new_forbes["age"][i] < 61:
        result = 'middle age'
    elif new_forbes["age"][i] < 101:
        result = 'old age'
    else:
        result = 'NA'
        
    age_classification.append(result)
    
#create a new column to assign BMI scores
new_forbes['Age Classification'] = age_classification

print(new_forbes)
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0      219000             Automotive
# 1        2                Jeff Bezos  58.0      171000             Technology
# 2        3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3        4                Bill Gates  66.0      129000             Technology
# 4        5            Warren Buffett  91.0      118000  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0        1000          Manufacturing
# 2664  2578                Zhou Ruxin  59.0        1000             Technology
# 2665  2578         Wen Zhou & family  57.0        1000          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0        1000                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0        1000          Manufacturing
#
# ...

# %%
new_forbes.to_csv("forbesList.csv", index=False)
